# %%
import numpy as np
import pandas as pd
import os
import csv
import string
from nltk import pos_tag, word_tokenize

np.random.seed(10)

# %%
initial = {}
first_order = {} 
second_order = {}

# %%
def add2dict(d, k, v):
  if k not in d:
    d[k] = []
  d[k].append(v)

# [cat, cat, dog, dog, dog, dog, dog, mouse, ...]

# %%
path='C:/Mydata/natural_language_processing/bbc/business'
tokens=[]
for filename in os.listdir(path):
    file=[]
    for line in open(path+"/"+filename, encoding='utf-8'):
        file.append(line.rstrip().lower().split())
    tokens.append(file)

# %%
test_file_1_index = 1
test_file_2_index = 2
test_file_1= tokens[test_file_1_index]
test_file_2= tokens[test_file_2_index]
print(len(tokens))
del tokens[test_file_1_index],tokens[test_file_2_index]
print(len(tokens))
# Out:
# 510
# 508

# %%
# Remove empty lists [] from tokens

filtered_tokens=[]
for index, token in enumerate(tokens):
    filtered_list = [item for item in token if item]
    filtered_tokens.append(filtered_list)

# %%
filtered_tokens[0][0]
# Out:
# ['ad', 'sales', 'boost', 'time', 'warner', 'profit']

# %%
for doc_idx, doc in enumerate(filtered_tokens):
    for sentence_idx, sentence in enumerate(doc):
        for word_idx, word in enumerate(sentence):
            t = word
            initial[t] = initial.get(t, 0.) + 1
            if word_idx==0:
                t_p1 = sentence[word_idx+1]
                add2dict(first_order, t, t_p1)
            elif word_idx==len(sentence)-1:
                t_m1 = sentence[word_idx-1]
                add2dict(first_order, t_m1, t)
            else:
                t_m1 = sentence[word_idx-1]
                t_p1 = sentence[word_idx+1]
                add2dict(second_order, (t_m1, t_p1), t)

# %%
# normalize the distributions
initial_total = sum(initial.values())
for t, c in initial.items():
    initial[t] = c / initial_total

# %%
# convert [cat, cat, cat, dog, dog, dog, dog, mouse, ...]
# into {cat: 0.5, dog: 0.4, mouse: 0.1}

def list2pdict(ts):
  # turn each list of possibilities into a dictionary of probabilities
  d = {}
  n = len(ts)
  for t in ts:
    d[t] = d.get(t, 0.) + 1
  for t, c in d.items():
    d[t] = c / n
  return d

# %%
for t_1, ts in first_order.items():
  first_order[t_1] = list2pdict(ts)
for k, ts in second_order.items():
  second_order[k] = list2pdict(ts)

# %%
second_order
# Out:
# {('ad', 'boost'): {'sales': 1.0},
#  ('sales', 'time'): {'boost': 1.0},
#  ('boost', 'warner'): {'time': 1.0},
#  ('time', 'profit'): {'warner': 1.0},
#  ('quarterly', 'at'): {'profits': 1.0},
#  ('profits', 'us'): {'at': 1.0},
#  ('at', 'media'): {'us': 1.0},
#  ('us', 'giant'): {'media': 0.1,
#   'telecoms': 0.1,
#   'banking': 0.2,
#   'foods': 0.1,
#   'retail': 0.1,
#   'oil': 0.2,
#   'mortgage': 0.1,
#   'agrochemical': 0.1},
#  ('media', 'timewarner'): {'giant': 1.0},
#  ('giant', 'jumped'): {'timewarner': 1.0},
#  ('timewarner', '76%'): {'jumped': 1.0},
#  ('jumped', 'to'): {'76%': 0.5, '22%': 0.5},
#  ('76%', '$1.13bn'): {'to': 1.0},
#  ('to', '(£600m)'): {'$1.13bn': 1.0},
#  ('$1.13bn', 'for'): {'(£600m)': 1.0},
#  ('(£600m)', 'the'): {'for': 1.0},
#  ('for', 'three'): {'the': 1.0},
#  ('the', 'months'): {'three': 0.6206896551724138,
#   '12': 0.1724137931034483,
#   'six': 0.06896551724137931,
#   'early': 0.034482758620689655,
#   'last': 0.034482758620689655,
#   'busiest': 0.034482758620689655,
#   'five': 0.034482758620689655},
#  ('three', 'to'): {'months': 1.0},
#  ('months', 'december,'): {'to': 1.0},
#  ('to', 'from'): {'december,': 0.03278688524590164,
#   '$11.1bn': 0.01639344262295082,
#   'dvds': 0.01639344262295082,
#   '£170m': 0.01639344262295082,
#   '4.0%': 0.01639344262295082,
#   '1.8%': 0.01639344262295082,
#   '36%': 0.01639344262295082,
#   'resign': 0.03278688524590164,
#   'figures': 0.03278688524590164,
#   '£198m': 0.01639344262295082,
#   '5.4%': 0.01639344262295082,
#   '£160m': 0.01639344262295082,
#   '4.7%': 0.01639344262295082,
#   'sydney': 0.01639344262295082,
#   '51.8': 0.01639344262295082,
#   'fall': 0.04918032786885246,
#   'reports': 0.01639344262295082,
#   '5.5%': 0.01639344262295082,
#   '79,000': 0.01639344262295082,
#   '104.4': 0.01639344262295082,
#   'research': 0.01639344262295082,
#   '102.5,': 0.03278688524590164,
#   'move': 0.01639344262295082,
#   'drink': 0.01639344262295082,
#   'gain': 0.03278688524590164,
#   'estimates': 0.01639344262295082,
#   'benefit': 0.01639344262295082,
#   'steal': 0.01639344262295082,
#   'gauge': 0.03278688524590164,
#   '$3.1bn,': 0.01639344262295082,
#   'us': 0.01639344262295082,
#   'refrain': 0.01639344262295082,
#   'forecasts': 0.01639344262295082,
#   'emerge': 0.04918032786885246,
#   '72.0': 0.01639344262295082,
#   '67.4': 0.01639344262295082,
#   '49%': 0.01639344262295082,
#   '77,000,': 0.01639344262295082,
#   '449,603': 0.01639344262295082,
#   'come': 0.03278688524590164,
#   '$14.1bn': 0.01639344262295082,
#   '3%': 0.01639344262295082,
#   '£180,226,': 0.01639344262295082,
#   '7.1%': 0.01639344262295082,
#   'approval': 0.01639344262295082,
#   '£1.9bn': 0.01639344262295082,
#   '£2.7bn': 0.01639344262295082,
#   'recover': 0.01639344262295082,
#   '$935.8m': 0.01639344262295082,
#   '$51.2bn': 0.01639344262295082},
#  ('december,', '$639m'): {'from': 1.0},
#  ('from', 'year-earlier.'): {'$639m': 1.0},
#  ('the', 'which'): {'firm,': 0.10344827586206896,
#   'move': 0.017241379310344827,
#   'factors': 0.017241379310344827,
#   'dollar,': 0.034482758620689655,
#   '2.5%': 0.017241379310344827,
#   'farm,': 0.017241379310344827,
#   'company': 0.017241379310344827,
#   'business,': 0.017241379310344827,
#   'company,': 0.05172413793103448,
#   '777-200lr,': 0.017241379310344827,
#   'move,': 0.017241379310344827,
#   '$6bn': 0.017241379310344827,
#   'deal,': 0.06896551724137931,
#   'poll,': 0.034482758620689655,
#   'methodology': 0.017241379310344827,
#   'country,': 0.017241379310344827,
#   'malays': 0.017241379310344827,
#   'economy,': 0.017241379310344827,
#   'settlement,': 0.017241379310344827,
#   'consortium': 0.017241379310344827,
#   'us,': 0.034482758620689655,
#   'act,': 0.034482758620689655,
#   'club,': 0.017241379310344827,
#   'waves': 0.017241379310344827,
#   'decision,': 0.017241379310344827,
#   'borrowing,': 0.034482758620689655,
#   'government': 0.017241379310344827,
#   'lse,': 0.017241379310344827,
#   'unit,': 0.017241379310344827,
#   'independent,': 0.017241379310344827,
#   'division,': 0.017241379310344827,
#   'sale,': 0.017241379310344827,
#   'hurricanes,': 0.017241379310344827,
#   'ariary,': 0.017241379310344827,
#   'currency,': 0.017241379310344827,
#   'constitution,': 0.017241379310344827,
#   'tsunami': 0.017241379310344827,
#   'tsunami,': 0.017241379310344827,
#   'wsj,': 0.017241379310344827,
#   'earthquake': 0.017241379310344827,
#   'dispute': 0.017241379310344827,
#   'unit': 0.017241379310344827,
#   'group,': 0.017241379310344827},
#  ('firm,', 'is'): {'which': 1.0},
#  ('which', 'now'): {'is': 0.5, 'fiat': 0.25, 'has': 0.25},
#  ('is', 'one'): {'now': 0.2857142857142857,
#   'just': 0.42857142857142855,
#   'no': 0.14285714285714285,
#   'already': 0.14285714285714285},
#  ('now', 'of'): {'one': 0.3333333333333333,
#   'part': 0.3333333333333333,
#   'rid': 0.3333333333333333},
#  ('one', 'the'): {'of': 0.9803921568627451, 'from': 0.0196078431372549},
#  ('of', 'biggest'): {'the': 0.3076923076923077,
#   "ireland's": 0.07692307692307693,
#   'its': 0.15384615384615385,
#   "japan's": 0.07692307692307693,
#   "brazil's": 0.07692307692307693,
#   "m&s's": 0.07692307692307693,
#   "europe's": 0.07692307692307693,
#   "russia's": 0.07692307692307693,
#   "india's": 0.07692307692307693},
#  ('the', 'investors'): {'biggest': 0.5, 'same': 0.5},
#  ('biggest', 'in'): {'investors': 0.1111111111111111,
#   'jump': 0.1111111111111111,
#   'increase': 0.2222222222222222,
#   'player': 0.1111111111111111,
#   'slide': 0.1111111111111111,
#   'gainer': 0.1111111111111111,
#   'bank': 0.1111111111111111,
#   'banks': 0.1111111111111111},
#  ('investors', 'google,'): {'in': 1.0},
#  ('in', 'benefited'): {'google,': 1.0},
#  ('google,', 'from'): {'benefited': 1.0},
#  ('benefited', 'sales'): {'from': 1.0},
#  ('from', 'of'): {'sales': 0.14285714285714285,
#   'chelsea': 0.14285714285714285,
#   'bank': 0.2857142857142857,
#   'expectations': 0.14285714285714285,
#   'membership': 0.14285714285714285,
#   'members': 0.14285714285714285},
#  ('sales', 'high-speed'): {'of': 1.0},
#  ('of', 'internet'): {'high-speed': 0.5, 'stronger': 0.5},
#  ('high-speed', 'connections'): {'internet': 1.0},
#  ('internet', 'and'): {'connections': 0.3333333333333333,
#   'customers': 0.3333333333333333,
#   'services': 0.3333333333333333},
#  ('connections', 'higher'): {'and': 1.0},
#  ('and', 'advert'): {'higher': 1.0},
#  ('higher', 'sales.'): {'advert': 1.0},
#  ('advert', 'timewarner'): {'sales.': 1.0},
#  ('sales.', 'said'): {'timewarner': 0.5, 'gm': 0.5},
#  ('timewarner', 'fourth'): {'said': 1.0},
#  ('said', 'quarter'): {'fourth': 1.0},
#  ('fourth', 'sales'): {'quarter': 1.0},
#  ('quarter', 'rose'): {'sales': 1.0},
#  ('sales', '2%'): {'rose': 1.0},
#  ('rose', 'to'): {'2%': 0.04,
#   '12.3%': 0.04,
#   '$1.64': 0.04,
#   '2.8%': 0.04,
#   '2.3%': 0.04,
#   '3.6%': 0.04,
#   '32,000': 0.04,
#   '9%': 0.04,
#   '20%': 0.04,
#   '25%': 0.04,
#   '28%': 0.04,
#   '56%': 0.04,
#   '1%': 0.08,
#   '8%': 0.04,
#   '0.9%': 0.04,
#   '206,900': 0.04,
#   '3.5%': 0.04,
#   '3.8%': 0.04,
#   'again': 0.04,
#   '12%': 0.04,
#   '4.7%': 0.04,
#   '4.5%': 0.04,
#   '$7.2bn': 0.04,
#   '34%': 0.04},
#  ('2%', '$11.1bn'): {'to': 1.0},
#  ('$11.1bn', '$10.9bn.'): {'from': 1.0},
#  ('from', 'its'): {'$10.9bn.': 0.3333333333333333,
#   'running': 0.3333333333333333,
#   'cincinnati,': 0.3333333333333333},
#  ('$10.9bn.', 'profits'): {'its': 1.0},
#  ('its', 'were'): {'profits': 0.21428571428571427,
#   'shares': 0.2857142857142857,
#   'prices': 0.07142857142857142,
#   'plans': 0.07142857142857142,
#   'assets': 0.14285714285714285,
#   'interests': 0.07142857142857142,
#   'reserves': 0.07142857142857142,
#   'finances': 0.07142857142857142},
#  ('profits', 'buoyed'): {'were': 1.0},
#  ('were', 'by'): {'buoyed': 0.041666666666666664,
#   'triggered': 0.041666666666666664,
#   'boosted': 0.041666666666666664,
#   'produced': 0.041666666666666664,
#   'dampened': 0.041666666666666664,
#   'helped': 0.041666666666666664,
#   'shaken': 0.041666666666666664,
#   'delayed': 0.041666666666666664,
#   'affected': 0.041666666666666664,
#   'up': 0.125,
#   'dismissed': 0.041666666666666664,
#   'rung': 0.041666666666666664,
#   'developed': 0.041666666666666664,
#   'owed': 0.041666666666666664,
#   'cheered': 0.041666666666666664,
#   'delighted': 0.041666666666666664,
#   'given': 0.041666666666666664,
#   'employed': 0.041666666666666664,
#   'hit': 0.041666666666666664,
#   'unaffected': 0.041666666666666664,
#   'prompted': 0.041666666666666664,
#   'led': 0.041666666666666664},
#  ('buoyed', 'one-off'): {'by': 1.0},
#  ('by', 'gains'): {'one-off': 1.0},
#  ('one-off', 'which'): {'gains': 1.0},
#  ('gains', 'offset'): {'which': 1.0},
#  ('which', 'a'): {'offset': 0.08333333333333333,
#   'has': 0.25,
#   'showed': 0.08333333333333333,
#   'produced': 0.08333333333333333,
#   'enjoyed': 0.08333333333333333,
#   'includes': 0.08333333333333333,
#   'became': 0.08333333333333333,
#   'owns': 0.08333333333333333,
#   'played': 0.08333333333333333,
#   'continued': 0.08333333333333333},
#  ('offset', 'profit'): {'a': 1.0},
#  ('a', 'dip'): {'profit': 0.5, 'slight': 0.5},
#  ('profit', 'at'): {'dip': 0.5, 'margins': 0.5},
#  ('dip', 'warner'): {'at': 1.0},
#  ('at', 'bros,'): {'warner': 1.0},
#  ('warner', 'and'): {'bros,': 1.0},
#  ('bros,', 'less'): {'and': 1.0},
#  ('and', 'users'): {'less': 1.0},
#  ('less', 'for'): {'users': 0.3333333333333333,
#   'risky': 0.3333333333333333,
#   'than': 0.3333333333333333},
#  ('users', 'aol.'): {'for': 1.0},
#  ('time', 'said'): {'warner': 1.0},
#  ('warner', 'on'): {'said': 1.0},
#  ('said', 'friday'): {'on': 1.0},
#  ('on', 'that'): {'friday': 0.1388888888888889,
#   'speculation': 0.1388888888888889,
#   'agriculture': 0.027777777777777776,
#   'thursday': 0.08333333333333333,
#   'wednesday': 0.1111111111111111,
#   'planes': 0.027777777777777776,
#   'tuesday': 0.19444444444444445,
#   'reports': 0.027777777777777776,
#   'fears': 0.027777777777777776,
#   'concerns': 0.027777777777777776,
#   'sunday': 0.1111111111111111,
#   'monday': 0.05555555555555555,
#   'news': 0.027777777777777776},
#  ('friday', 'it'): {'that': 1.0},
#  ('that', 'now'): {'it': 0.25, 'they': 0.25, 'he': 0.25, 'anyone': 0.25},
#  ('it', 'owns'): {'now': 0.6666666666666666, 'also': 0.3333333333333333},
#  ('now', '8%'): {'owns': 1.0},
#  ('owns', 'of'): {'8%': 0.1,
#   '55%': 0.1,
#   '6.7%': 0.1,
#   'much': 0.1,
#   '44%': 0.1,
#   '30%': 0.1,
#   '51.4%': 0.1,
#   '82%': 0.1,
#   '46%': 0.1,
#   '40%': 0.1},
#  ('8%', 'search-engine'): {'of': 1.0},
#  ('of', 'google.'): {'search-engine': 1.0},
#  ('search-engine', 'but'): {'google.': 1.0},
#  ('google.', 'its'): {'but': 1.0},
#  ('but', 'own'): {'its': 1.0},
#  ('its', 'internet'): {'own': 0.5, 'broadband': 0.5},
#  ('own', 'business,'): {'internet': 0.5, 'consulting': 0.5},
#  ('internet', 'aol,'): {'business,': 1.0},
#  ('business,', 'had'): {'aol,': 1.0},
#  ('aol,', 'has'): {'had': 1.0},
#  ('had', 'mixed'): {'has': 1.0},
#  ('has', 'fortunes.'): {'mixed': 1.0},
#  ('mixed', 'it'): {'fortunes.': 1.0},
#  ('fortunes.', 'lost'): {'it': 1.0},
#  ('it', '464,000'): {'lost': 1.0},
#  ('lost', 'subscribers'): {'464,000': 1.0},
#  ('464,000', 'in'): {'subscribers': 1.0},
#  ('subscribers', 'the'): {'in': 0.5, 'at': 0.5},
#  ('in', 'fourth'): {'the': 1.0},
#  ('the', 'quarter'): {'fourth': 0.32075471698113206,
#   'third': 0.1320754716981132,
#   'first': 0.20754716981132076,
#   'last': 0.18867924528301888,
#   'second': 0.09433962264150944,
#   'final': 0.05660377358490566},
#  ('fourth', 'profits'): {'quarter': 1.0},
#  ('quarter', 'were'): {'profits': 1.0},
#  ('profits', 'lower'): {'were': 1.0},
#  ('were', 'than'): {'lower': 0.3333333333333333, 'better': 0.6666666666666666},
#  ('lower', 'in'): {'than': 0.7142857142857143,
#   'turnover.': 0.14285714285714285,
#   'prices': 0.14285714285714285},
#  ('than', 'the'): {'in': 0.23809523809523808,
#   'expected.': 0.047619047619047616,
#   'forecast.': 0.047619047619047616,
#   'malt.': 0.047619047619047616,
#   'for': 0.047619047619047616,
#   'expected': 0.047619047619047616,
#   '$5bn,': 0.047619047619047616,
#   'buy': 0.047619047619047616,
#   'half': 0.09523809523809523,
#   'at': 0.19047619047619047,
#   '£230m.': 0.047619047619047616,
#   'during': 0.047619047619047616,
#   'before': 0.047619047619047616},
#  ('in', 'preceding'): {'the': 1.0},
#  ('the', 'three'): {'preceding': 0.021739130434782608,
#   'past': 0.13043478260869565,
#   'last': 0.2826086956521739,
#   'next': 0.2391304347826087,
#   'first': 0.021739130434782608,
#   'final': 0.15217391304347827,
#   'previous': 0.021739130434782608,
#   'weekend.': 0.021739130434782608,
#   'china': 0.043478260869565216,
#   'main': 0.021739130434782608,
#   'country': 0.021739130434782608,
#   '$22bn': 0.021739130434782608},
#  ('preceding', 'quarters.'): {'three': 1.0},
#  ('three', 'however,'): {'quarters.': 1.0},
#  ('quarters.', 'the'): {'however,': 1.0},
#  ('however,', 'company'): {'the': 1.0},
#  ('the', 'said'): {'company': 0.1476510067114094,
#   'wsj': 0.006711409395973154,
#   'nhtsa': 0.006711409395973154,
#   'government': 0.026845637583892617,
#   'authorities': 0.006711409395973154,
#   'sec': 0.013422818791946308,
#   'newspaper': 0.013422818791946308,
#   'economy,"': 0.006711409395973154,
#   'airline': 0.020134228187919462,
#   'paper': 0.020134228187919462,
#   'bank': 0.04697986577181208,
#   'firm': 0.10738255033557047,
#   'airlines?"': 0.006711409395973154,
#   'eu': 0.026845637583892617,
#   'report': 0.006711409395973154,
#   'kremlin': 0.006711409395973154,
#   'cips': 0.006711409395973154,
#   'industry,"': 0.006711409395973154,
#   'insurer': 0.006711409395973154,
#   'imf': 0.020134228187919462,
#   'charges,"': 0.006711409395973154,
#   'commission': 0.006711409395973154,
#   'cbi,': 0.006711409395973154,
#   'subsidy,"': 0.006711409395973154,
#   'fed': 0.006711409395973154,
#   'first,"': 0.006711409395973154,
#   'ministry': 0.013422818791946308,
#   'unions': 0.006711409395973154,
#   'us,': 0.013422818791946308,
#   'companies': 0.020134228187919462,
#   'treasury': 0.013422818791946308,
#   'deal': 0.006711409395973154,
#   'cbi': 0.006711409395973154,
#   'unece': 0.006711409395973154,
#   'organisation': 0.006711409395973154,
#   'us': 0.026845637583892617,
#   'fda': 0.006711409395973154,
#   'cml': 0.020134228187919462,
#   'bsa': 0.006711409395973154,
#   'bba': 0.006711409395973154,
#   'group': 0.013422818791946308,
#   'ft': 0.020134228187919462,
#   'year,"': 0.006711409395973154,
#   'lse': 0.013422818791946308,
#   'club': 0.013422818791946308,
#   'tuc': 0.006711409395973154,
#   'caribbean': 0.006711409395973154,
#   'missing,"': 0.006711409395973154,
#   'bundesbank,': 0.006711409395973154,
#   'brc': 0.013422818791946308,
#   'ons': 0.026845637583892617,
#   'eef,': 0.013422818791946308,
#   'wto': 0.013422818791946308,
#   'auction,': 0.006711409395973154,
#   'financing,"': 0.006711409395973154,
#   'crisis,"': 0.006711409395973154,
#   'iceberg,"': 0.006711409395973154,
#   'other,"': 0.006711409395973154,
#   'vice-chairman,': 0.006711409395973154,
#   'ism': 0.006711409395973154,
#   'contract,': 0.006711409395973154,
#   'dollar,"': 0.006711409395973154,
#   'official': 0.006711409395973154,
#   'lawsuit,': 0.006711409395973154,
#   'nationwide': 0.006711409395973154,
#   'period,': 0.006711409395973154,
#   'adb': 0.006711409395973154,
#   'brewer': 0.006711409395973154,
#   'company,"': 0.006711409395973154,
#   'quarter,"': 0.006711409395973154,
#   'public,"': 0.006711409395973154,
#   'market,"': 0.006711409395973154},
#  ('company', "aol's"): {'said': 1.0},
#  ('said', 'underlying'): {"aol's": 0.5, 'its': 0.5},
#  ("aol's", 'profit'): {'underlying': 1.0},
#  ('underlying', 'before'): {'profit': 1.0},
#  ('profit', 'exceptional'): {'before': 1.0},
#  ('before', 'items'): {'exceptional': 1.0},
#  ('exceptional', 'rose'): {'items': 1.0},
#  ('items', '8%'): {'rose': 1.0},
#  ('rose', 'on'): {'8%': 0.14285714285714285,
#   'again': 0.14285714285714285,
#   'temporarily': 0.14285714285714285,
#   '3.8%': 0.14285714285714285,
#   '1%': 0.14285714285714285,
#   'sharply': 0.14285714285714285,
#   '0.6%': 0.14285714285714285},
#  ('8%', 'the'): {'on': 0.5, 'for': 0.5},
#  ('on', 'back'): {'the': 1.0},
#  ('the', 'of'): {'back': 0.0058823529411764705,
#   'lord': 0.0008403361344537816,
#   'sale': 0.025210084033613446,
#   'value': 0.0226890756302521,
#   'owners': 0.0025210084033613447,
#   'buyer': 0.0016806722689075631,
#   'rule': 0.0016806722689075631,
#   'target': 0.0058823529411764705,
#   'performance': 0.0008403361344537816,
#   'brink': 0.0067226890756302525,
#   'face': 0.010084033613445379,
#   'average': 0.0008403361344537816,
#   'effects': 0.0058823529411764705,
#   'dangers': 0.0025210084033613447,
#   'court': 0.0008403361344537816,
#   'district': 0.0025210084033613447,
#   'notice': 0.0008403361344537816,
#   'lifeblood': 0.0008403361344537816,
#   'quality': 0.005042016806722689,
#   'news': 0.0008403361344537816,
#   'length': 0.0016806722689075631,
#   'fault': 0.0008403361344537816,
#   'shape': 0.0008403361344537816,
#   'level': 0.0067226890756302525,
#   'centre': 0.007563025210084034,
#   'number': 0.024369747899159664,
#   'idea': 0.0008403361344537816,
#   'risk': 0.0058823529411764705,
#   'announcement': 0.0008403361344537816,
#   'competitiveness': 0.0033613445378151263,
#   'brunt': 0.0008403361344537816,
#   'government': 0.0033613445378151263,
#   'top': 0.004201680672268907,
#   'end': 0.04201680672268908,
#   'health': 0.0033613445378151263,
#   'rest': 0.009243697478991597,
#   'auction': 0.0025210084033613447,
#   'rulings': 0.0008403361344537816,
#   'ability': 0.0008403361344537816,
#   'ownership': 0.0008403361344537816,
#   'merits': 0.0025210084033613447,
#   'acquisition': 0.0008403361344537816,
#   'south': 0.0016806722689075631,
#   'legality': 0.0008403361344537816,
#   'forecast': 0.009259259259259259,
#   'wants': 0.07407407407407407,
#   'has': 0.018518518518518517,
#   'harder': 0.009259259259259259,
#   'hoped': 0.027777777777777776,
#   'expects': 0.07407407407407407,
#   'plans': 0.05555555555555555,
#   'is': 0.10185185185185185,
#   'had': 0.009259259259259259,
#   'tries': 0.018518518518518517,
#   'expected': 0.027777777777777776,
#   'planned': 0.037037037037037035,
#   'access': 0.009259259259259259,
#   'hard': 0.009259259259259259,
#   'seeks': 0.018518518518518517,
#   'agreed': 0.027777777777777776,
#   'pointed': 0.009259259259259259,
#   'wanted': 0.018518518518518517,
#   'pledged': 0.009259259259259259,
#   'owed': 0.009259259259259259,
#   'was': 0.018518518518518517,
#   'continued': 0.018518518518518517,
#   'alleges': 0.009259259259259259,
#   'sought': 0.009259259259259259,
#   'difficult': 0.027777777777777776,
#   'mutates': 0.009259259259259259,
#   'unrelated': 0.009259259259259259,
#   'aims': 0.027777777777777776,
#   'comes': 0.009259259259259259,
#   'failed': 0.018518518518518517,
#   'came': 0.009259259259259259,
#   'takes': 0.009259259259259259,
#   'fails': 0.027777777777777776,
#   'continues': 0.018518518518518517,
#   'easier': 0.018518518518518517,
#   'down': 0.009259259259259259,
#   'return': 0.009259259259259259,
#   'struggles': 0.009259259259259259,
#   'refused': 0.009259259259259259,
#   'elevated': 0.009259259259259259,
#   'falling': 0.009259259259259259,
#   'referred': 0.009259259259259259,
#   'needs': 0.009259259259259259,
#   'struggled': 0.009259259259259259,
#   'looks': 0.009259259259259259,
#   'fell': 0.009259259259259259},
#  ('hopes', 'increase'): {'to': 1.0},
#  ('to', 'subscribers'): {'increase': 1.0},
#  ('increase', 'by'): {'subscribers': 0.3333333333333333,
#   'addiction': 0.3333333333333333,
#   'productivity': 0.3333333333333333},
#  ('subscribers', 'offering'): {'by': 1.0},
#  ('by', 'the'): {'offering': 0.04,
#   'country.': 0.04,
#   '2008.': 0.08,
#   '72%': 0.04,
#   'allowing': 0.04,
#   'far': 0.08,
#   '0.8%,': 0.04,
#   'forecasters.': 0.04,
#   'coating': 0.04,
#   'reviewing': 0.04,
#   'carnival,': 0.04,
#   'definition,': 0.04,
#   'lessening': 0.08,
#   'selling': 0.04,
#   'asbestos': 0.04,
#   'signing': 0.04,
#   'expanding': 0.04,
#   'surprise,"': 0.04,
#   'constellation,': 0.04,
#   'amf.': 0.04,
#   '2010.': 0.04,
#   'pushing': 0.04},
#  ('offering', 'online'): {'the': 1.0},
#  ('the', 'service'): {'online': 0.25,
#   'secret': 0.25,
#   'easymobile': 0.25,
#   'new': 0.25},
#  ('online', 'free'): {'service': 1.0},
#  ('service', 'to'): {'free': 1.0},
#  ('free', 'timewarner'): {'to': 1.0},
#  ('to', 'internet'): {'timewarner': 1.0},
#  ('timewarner', 'customers'): {'internet': 1.0},
#  ('customers', 'will'): {'and': 1.0},
#  ('and', 'try'): {'will': 1.0},
#  ('will', 'to'): {'try': 0.015625,
#   'have': 0.328125,
#   'apply': 0.015625,
#   'continue': 0.140625,
#   'lead': 0.109375,
#   'want': 0.015625,
#   'need': 0.109375,
#   'happen': 0.015625,
#   'return': 0.03125,
#   'come': 0.015625,
#   'increase': 0.015625,
#   'agree': 0.015625,
#   'live': 0.015625,
#   'begin': 0.03125,
#   'double': 0.015625,
#   'decline': 0.015625,
#   'slow': 0.015625,
#   'attempt': 0.015625,
#   'struggle': 0.015625,
#   'offer': 0.015625,
#   'fall': 0.015625,
#   'listen': 0.015625},
#  ('try', 'sign'): {'to': 1.0},
#  ('to', 'up'): {'sign': 0.03773584905660377,
#   'shake': 0.03773584905660377,
#   'set': 0.09433962264150944,
#   'end': 0.018867924528301886,
#   'december': 0.018867924528301886,
#   'keep': 0.07547169811320754,
#   'back': 0.018867924528301886,
#   'cover': 0.018867924528301886,
#   'sell': 0.018867924528301886,
#   'open': 0.05660377358490566,
#   'give': 0.05660377358490566,
#   'go': 0.018867924528301886,
#   'make': 0.018867924528301886,
#   'raise': 0.018867924528301886,
#   'speed': 0.018867924528301886,
#   'pick': 0.07547169811320754,
#   'stand': 0.018867924528301886,
#   'top': 0.03773584905660377,
#   'offer': 0.018867924528301886,
#   'draw': 0.03773584905660377,
#   'build': 0.018867924528301886,
#   'brighten': 0.018867924528301886,
#   'add': 0.018867924528301886,
#   'clean': 0.05660377358490566,
#   'pay': 0.018867924528301886,
#   'talk': 0.018867924528301886,
#   'come': 0.018867924528301886,
#   'link': 0.018867924528301886,
#   'snap': 0.018867924528301886,
#   'pile': 0.018867924528301886,
#   'take': 0.018867924528301886,
#   'stump': 0.018867924528301886,
#   'shore': 0.018867924528301886},
#  ('sign', "aol's"): {'up': 1.0},
#  ('up', 'existing'): {"aol's": 1.0},
#  ("aol's", 'customers'): {'existing': 1.0},
#  ('existing', 'for'): {'customers': 1.0},
#  ('customers', 'high-speed'): {'for': 1.0},
#  ('for', 'broadband.'): {'high-speed': 1.0},
#  ('high-speed', 'timewarner'): {'broadband.': 1.0},
#  ('broadband.', 'also'): {'timewarner': 1.0},
#  ('timewarner', 'has'): {'also': 1.0},
#  ('also', 'to'): {'has': 0.044444444444444446,
#   'attempted': 0.022222222222222223,
#   'failed': 0.044444444444444446,
#   'promised': 0.022222222222222223,
#   'managed': 0.022222222222222223,
#   'agreed': 0.06666666666666667,
#   'threatened': 0.022222222222222223,
#   'fell': 0.022222222222222223,
#   'led': 0.022222222222222223,
#   'hopes': 0.044444444444444446,
#   'contributed': 0.022222222222222223,
#   'served': 0.044444444444444446,
#   'linked': 0.022222222222222223,
#   'expected': 0.044444444444444446,
#   'hostile': 0.022222222222222223,
#   'seek': 0.022222222222222223,
#   'plans': 0.022222222222222223,
#   'applies': 0.044444444444444446,
#   'seeking': 0.022222222222222223,
#   'set': 0.022222222222222223,
#   'wants': 0.022222222222222223,
#   'pledged': 0.044444444444444446,
#   'said': 0.044444444444444446,
#   'looking': 0.022222222222222223,
#   'rose': 0.022222222222222223,
#   'hope': 0.022222222222222223,
#   'offered': 0.022222222222222223,
#   'struggling': 0.022222222222222223,
#   'eased': 0.022222222222222223,
#   'trying': 0.022222222222222223,
#   'important': 0.022222222222222223,
#   'appeared': 0.022222222222222223,
#   'going': 0.022222222222222223,
#   'begun': 0.022222222222222223,
#   'want': 0.022222222222222223},
#  ('has', 'restate'): {'to': 1.0},
#  ('to', '2000'): {'restate': 1.0},
#  ('restate', 'and'): {'2000': 1.0},
#  ('2000', '2003'): {'and': 1.0},
#  ('and', 'results'): {'2003': 1.0},
#  ('2003', 'following'): {'results': 1.0},
#  ('results', 'a'): {'following': 0.5, 'with': 0.5},
#  ('following', 'probe'): {'a': 1.0},
#  ('a', 'by'): {'probe': 0.10526315789473684,
#   'takeover': 0.05263157894736842,
#   'bit': 0.05263157894736842,
#   'buyout': 0.10526315789473684,
#   'review': 0.05263157894736842,
#   'mistake': 0.05263157894736842,
#   'drive': 0.10526315789473684,
#   'member': 0.05263157894736842,
#   'plane': 0.05263157894736842,
#   'stake': 0.05263157894736842,
#   'fortune': 0.10526315789473684,
#   'third': 0.05263157894736842,
#   'movement': 0.05263157894736842,
#   'decision': 0.05263157894736842,
#   'survey': 0.05263157894736842},
#  ('probe', 'the'): {'by': 1.0},
#  ('by', 'us'): {'the': 0.6153846153846154,
#   'any': 0.07692307692307693,
#   'new': 0.07692307692307693,
#   'a': 0.15384615384615385,
#   'sluggish': 0.07692307692307693},
#  ('the', 'securities'): {'us': 1.0},
#  ('us', 'exchange'): {'securities': 1.0},
#  ('securities', 'commission'): {'exchange': 1.0},
#  ('exchange', '(sec),'): {'commission': 1.0},
#  ('commission', 'which'): {'(sec),': 0.5, 'ruling': 0.5},
#  ('(sec),', 'is'): {'which': 1.0},
#  ('which', 'close'): {'is': 1.0},
#  ('is', 'to'): {'close': 0.010752688172043012,
#   'home': 0.0035842293906810036,
#   'continuing': 0.014336917562724014,
#   'unlikely': 0.021505376344086023,
#   'expected': 0.16487455197132617,
#   'moved': 0.0035842293906810036,
#   'pegged': 0.0035842293906810036,
#   'likely': 0.0967741935483871,
#   'resolved': 0.0035842293906810036,
#   'due': 0.04659498207885305,
#   'used': 0.014336917562724014,
#   'forecast': 0.025089605734767026,
#   'scheduled': 0.014336917562724014,
#   'aiming': 0.0035842293906810036,
#   'enough': 0.0035842293906810036,
#   'action': 0.0035842293906810036,
#   'thought': 0.03225806451612903,
#   'designed': 0.02867383512544803,
#   'set': 0.08243727598566308,
#   'said': 0.021505376344086023,
#   'next': 0.0035842293906810036,
#   'prepared': 0.0035842293906810036,
#   'up': 0.007168458781362007,
#   'here': 0.0035842293906810036,
#   'key': 0.0035842293906810036,
#   'planning': 0.021505376344086023,
#   'hoping': 0.010752688172043012,
#   'necessary': 0.0035842293906810036,
#   'considering': 0.0035842293906810036,
#   'going': 0.02867383512544803,
#   'believed': 0.017921146953405017,
#   'trying': 0.03942652329749104,
#   'preparing': 0.0035842293906810036,
#   'projected': 0.007168458781362007,
#   'intended': 0.007168458781362007,
#   'down': 0.0035842293906810036,
#   'possible': 0.0035842293906810036,
#   'committed': 0.010752688172043012,
#   'similar': 0.0035842293906810036,
#   '"trying': 0.0035842293906810036,
#   'identical': 0.0035842293906810036,
#   'reported': 0.021505376344086023,
#   'proving': 0.0035842293906810036,
#   'tipped': 0.0035842293906810036,
#   'estimated': 0.0035842293906810036,
#   'seeking': 0.010752688172043012,
#   'obliged': 0.0035842293906810036,
#   'willing': 0.007168458781362007,
#   'subject': 0.014336917562724014,
#   'looking': 0.014336917562724014,
#   'important': 0.0035842293906810036,
#   'allowed': 0.0035842293906810036,
#   'imperative': 0.0035842293906810036,
#   'useful': 0.0035842293906810036,
#   'essential': 0.007168458781362007,
#   'now': 0.0035842293906810036,
#   'yet': 0.0035842293906810036,
#   'keen': 0.010752688172043012,
#   'needed': 0.007168458781362007,
#   'indifferent': 0.0035842293906810036,
#   'rumoured': 0.0035842293906810036,
#   'starting': 0.007168458781362007,
#   'free': 0.0035842293906810036,
#   'refusing': 0.0035842293906810036,
#   'easy': 0.0035842293906810036,
#   'doomed': 0.0035842293906810036,
#   'having': 0.014336917562724014,
#   'poised': 0.0035842293906810036,
#   'supposed': 0.0035842293906810036,
#   'able': 0.0035842293906810036,
#   'dedicated': 0.0035842293906810036,
#   'happy': 0.0035842293906810036,
#   'impossible': 0.0035842293906810036,
#   'required': 0.0035842293906810036,
#   'threatening': 0.0035842293906810036,
#   'fixed': 0.0035842293906810036,
#   'struggling': 0.0035842293906810036},
#  ('close', 'concluding.'): {'to': 1.0},
#  ('time', 'fourth'): {"warner's": 1.0},
#  ("warner's", 'quarter'): {'fourth': 1.0},
#  ('profits', 'slightly'): {'were': 1.0},
#  ('were', 'better'): {'slightly': 1.0},
#  ('slightly', 'than'): {'better': 0.5,
#   'higher': 0.3333333333333333,
#   'lower': 0.16666666666666666},
#  ('better', "analysts'"): {'than': 1.0},
#  ('than', 'expectations.'): {"analysts'": 1.0},
#  ("analysts'", 'but'): {'expectations.': 1.0},
#  ('expectations.', 'its'): {'but': 1.0},
#  ('but', 'film'): {'its': 1.0},
#  ('its', 'division'): {'film': 0.3333333333333333,
#   'yugansk': 0.3333333333333333,
#   'car': 0.3333333333333333},
#  ('film', 'saw'): {'division': 1.0},
#  ('division', 'profits'): {'saw': 0.5, 'report': 0.5},
#  ('saw', 'slump'): {'profits': 1.0},
#  ('profits', '27%'): {'slump': 1.0},
#  ('slump', 'to'): {'27%': 1.0},
#  ('27%', '$284m,'): {'to': 1.0},
#  ('to', 'helped'): {'$284m,': 1.0},
#  ('$284m,', 'by'): {'helped': 1.0},
#  ('helped', 'box-office'): {'by': 1.0},
#  ('by', 'flops'): {'box-office': 1.0},
#  ('box-office', 'alexander'): {'flops': 1.0},
#  ('flops', 'and'): {'alexander': 1.0},
#  ('alexander', 'catwoman,'): {'and': 1.0},
#  ('and', 'a'): {'catwoman,': 0.029411764705882353,
#   'gazpromneft,': 0.058823529411764705,
#   'now': 0.029411764705882353,
#   'ran': 0.029411764705882353,
#   'not': 0.029411764705882353,
#   'shochu,': 0.029411764705882353,
#   'made': 0.029411764705882353,
#   'becoming': 0.029411764705882353,
#   'pound': 0.003937007874015748,
#   'delay': 0.003937007874015748,
#   'australian': 0.007874015748031496,
#   'merchandising': 0.003937007874015748,
#   'month': 0.007874015748031496,
#   'budget': 0.007874015748031496,
#   '"legal': 0.003937007874015748,
#   'auction,': 0.003937007874015748,
#   'project': 0.003937007874015748,
#   'spring': 0.003937007874015748,
#   'chinese': 0.003937007874015748,
#   'amstel': 0.003937007874015748,
#   'packaging': 0.003937007874015748,
#   'pills': 0.003937007874015748,
#   'wto': 0.007874015748031496,
#   'bilateral': 0.003937007874015748,
#   'telecommunications': 0.003937007874015748,
#   'will': 0.003937007874015748,
#   'factory': 0.003937007874015748,
#   'stadium': 0.003937007874015748,
#   'mangala': 0.003937007874015748,
#   'economy': 0.011811023622047244,
#   'peaks': 0.007874015748031496,
#   'world': 0.011811023622047244,
#   'coldplay': 0.003937007874015748,
#   'performance': 0.003937007874015748,
#   'polls,': 0.007874015748031496,
#   'lse.': 0.003937007874015748,
#   'club,': 0.003937007874015748,
#   'direct': 0.003937007874015748,
#   'poorest': 0.003937007874015748,
#   'statement': 0.003937007874015748,
#   'g7': 0.003937007874015748,
#   'club': 0.003937007874015748,
#   'roof': 0.003937007874015748,
#   'character': 0.003937007874015748,
#   'power': 0.003937007874015748,
#   'insulation': 0.003937007874015748,
#   'lighting': 0.003937007874015748,
#   'screen': 0.003937007874015748,
# ...
#  ('seagram', 'to'): {'purchase': 1.0},
#  ('purchase', 'just'): {'to': 1.0},
#  ('to', '1.8bn'): {'just': 1.0},
#  ('just', 'euros,'): {'1.8bn': 1.0},
#  ('1.8bn', 'while'): {'euros,': 1.0},
#  ('euros,', 'allied'): {'while': 1.0},
#  ('while', 'has'): {'allied': 0.14285714285714285,
#   'russia': 0.14285714285714285,
#   'there': 0.14285714285714285,
#   'it': 0.14285714285714285,
#   'halliburton': 0.14285714285714285,
#   'euronext': 0.14285714285714285,
#   'india': 0.14285714285714285},
#  ('allied', 'improved'): {'has': 1.0},
#  ('improved', 'performance'): {'the': 1.0},
#  ('performance', 'its'): {'of': 1.0},
#  ('of', 'fast-food'): {'its': 1.0},
#  ('its', 'chains.'): {'fast-food': 1.0},
#  ('japan', 'escapes'): {'narrowly': 1.0},
#  ('narrowly', 'recession'): {'escapes': 1.0},
#  ("japan's", 'teetered'): {'economy': 1.0},
#  ('economy', 'on'): {'teetered': 0.4, 'back': 0.2, 'is': 0.4},
#  ('teetered', 'the'): {'on': 1.0},
#  ('on', 'brink'): {'the': 1.0},
#  ('brink', 'a'): {'of': 1.0},
#  ('of', 'technical'): {'a': 0.5, 'peoplesoft': 0.5},
#  ('a', 'recession'): {'technical': 1.0},
#  ('technical', 'in'): {'recession': 1.0},
#  ('recession', 'the'): {'in': 0.25, 'for': 0.25, 'and': 0.25, 'of': 0.25},
#  ('in', 'three'): {'the': 0.875, 'almost': 0.0625, 'these': 0.0625},
#  ('months', 'september,'): {'to': 1.0},
#  ('to', 'figures'): {'september,': 0.5, 'lending': 0.5},
#  ('september,', 'show.'): {'figures': 1.0},
#  ('revised', 'indicated'): {'figures': 1.0},
#  ('figures', 'growth'): {'indicated': 1.0},
#  ('indicated', 'of'): {'growth': 1.0},
#  ('growth', 'just'): {'of': 1.0},
#  ('of', '0.1%'): {'just': 1.0},
#  ('just', '-'): {'0.1%': 1.0},
#  ('0.1%', 'and'): {'-': 1.0},
#  ('-', 'a'): {'and': 0.07407407407407407,
#   'when': 0.037037037037037035,
#   'mark': 0.037037037037037035,
#   'itself': 0.037037037037037035,
#   'to': 0.037037037037037035,
#   'in': 0.1111111111111111,
#   'himself': 0.037037037037037035,
#   'obscured': 0.037037037037037035,
#   'transformed': 0.037037037037037035,
#   'announced': 0.037037037037037035,
#   'showing': 0.037037037037037035,
#   '300p': 0.037037037037037035,
#   'with': 0.037037037037037035,
#   'into': 0.037037037037037035,
#   'prompting': 0.037037037037037035,
#   'provoked': 0.037037037037037035,
#   'dominate': 0.037037037037037035,
#   'won': 0.037037037037037035,
#   'or': 0.037037037037037035,
#   'told': 0.037037037037037035,
#   'was': 0.037037037037037035,
#   'at': 0.037037037037037035,
#   'prompted': 0.037037037037037035,
#   'from': 0.037037037037037035},
#  ('and', 'similar-sized'): {'a': 1.0},
#  ('a', 'contraction'): {'similar-sized': 0.5, '0.1%': 0.5},
#  ('similar-sized', 'in'): {'contraction': 1.0},
#  ('contraction', 'the'): {'in': 1.0},
#  ('in', 'previous'): {'the': 1.0},
#  ('the', 'quarter.'): {'previous': 0.3076923076923077,
#   'third': 0.23076923076923078,
#   'fourth': 0.15384615384615385,
#   'last': 0.07692307692307693,
#   'second': 0.15384615384615385,
#   'october-to-december': 0.07692307692307693},
#  ('previous', 'on'): {'quarter.': 1.0},
#  ('quarter.', 'an'): {'on': 1.0},
#  ('on', 'annual'): {'an': 1.0},
#  ('an', 'basis,'): {'annual': 0.5, 'annualised': 0.5},
#  ('annual', 'the'): {'basis,': 0.2, 'accounts.': 0.4, 'budget.': 0.4},
#  ('basis,', 'data'): {'the': 1.0},
#  ('the', 'suggests'): {'data': 0.25, 'evidence': 0.5, 'survey': 0.25},
#  ('data', 'annual'): {'suggests': 1.0},
#  ('suggests', 'growth'): {'annual': 1.0},
#  ('annual', 'of'): {'growth': 0.07692307692307693,
#   'sales': 0.15384615384615385,
#   'rate': 0.46153846153846156,
#   'savings': 0.038461538461538464,
#   'profit': 0.038461538461538464,
#   'turnover': 0.038461538461538464,
#   'profits': 0.038461538461538464,
#   'revenues': 0.038461538461538464,
#   'income': 0.038461538461538464,
#   'capacity': 0.038461538461538464,
#   'investment': 0.038461538461538464},
#  ('of', '0.2%,'): {'just': 1.0},
#  ('just', 'suggesting'): {'0.2%,': 1.0},
#  ('0.2%,', 'a'): {'suggesting': 1.0},
#  ('suggesting', 'much'): {'a': 1.0},
#  ('a', 'more'): {'much': 0.1111111111111111,
#   'gamble,': 0.1111111111111111,
#   'lot': 0.2222222222222222,
#   'bit': 0.2222222222222222,
#   'third': 0.1111111111111111,
#   'takeover': 0.1111111111111111,
#   'little': 0.1111111111111111},
#  ('much', 'hesitant'): {'more': 1.0},
#  ('more', 'recovery'): {'hesitant': 1.0},
#  ('hesitant', 'than'): {'recovery': 1.0},
#  ('recovery', 'had'): {'than': 0.5, 'plan,': 0.5},
#  ('than', 'previously'): {'had': 1.0},
#  ('had', 'been'): {'previously': 0.14285714285714285,
#   'systematically': 0.14285714285714285,
#   'not': 0.35714285714285715,
#   'already': 0.14285714285714285,
#   'indeed': 0.07142857142857142,
#   'also': 0.14285714285714285},
#  ('previously', 'thought.'): {'been': 1.0},
#  ('been', 'a'): {'thought.': 0.125,
#   'interrupted': 0.125,
#   'forecasting': 0.125,
#   'producing': 0.125,
#   'given': 0.125,
#   'for': 0.125,
#   'made': 0.125,
#   'pursuing': 0.125},
#  ('thought.', 'common'): {'a': 1.0},
#  ('a', 'technical'): {'common': 1.0},
#  ('common', 'definition'): {'technical': 1.0},
#  ('technical', 'of'): {'definition': 1.0},
#  ('definition', 'a'): {'of': 1.0},
#  ('of', 'recession'): {'a': 1.0},
#  ('a', 'is'): {'recession': 0.15384615384615385,
#   'passenger': 0.07692307692307693,
#   'flight': 0.07692307692307693,
#   'decision': 0.07692307692307693,
#   'whole': 0.07692307692307693,
#   'firm': 0.07692307692307693,
#   'collapse': 0.07692307692307693,
#   'settlement': 0.07692307692307693,
#   'compromise': 0.07692307692307693,
#   'bid': 0.15384615384615385,
#   'plan': 0.07692307692307693},
#  ('recession', 'two'): {'is': 1.0},
#  ('is', 'successive'): {'two': 1.0},
#  ('two', 'quarters'): {'successive': 0.3333333333333333,
#   'consecutive': 0.3333333333333333,
#   'previous': 0.3333333333333333},
#  ('successive', 'of'): {'quarters': 1.0},
#  ('quarters', 'negative'): {'of': 1.0},
#  ('of', 'growth.'): {'negative': 0.2,
#   'sales': 0.2,
#   'economic': 0.2,
#   'rapid': 0.2,
#   'slow': 0.2},
#  ('the', 'was'): {'government': 0.04225352112676056,
#   'quarter': 0.007042253521126761,
#   'survey': 0.007042253521126761,
#   'firm': 0.035211267605633804,
#   'hood': 0.007042253521126761,
#   'outlook': 0.007042253521126761,
#   'sec': 0.007042253521126761,
#   'deadline': 0.007042253521126761,
#   'group': 0.007042253521126761,
#   'decline': 0.014084507042253521,
#   'airline': 0.007042253521126761,
#   'target': 0.007042253521126761,
#   'model': 0.007042253521126761,
#   'company': 0.04929577464788732,
#   'result': 0.007042253521126761,
#   'problem': 0.014084507042253521,
#   'deal': 0.035211267605633804,
#   'discrepancy': 0.007042253521126761,
#   'auction': 0.04929577464788732,
#   'dollar': 0.06338028169014084,
#   'respite': 0.007042253521126761,
#   'package': 0.007042253521126761,
#   'support': 0.007042253521126761,
#   'allegation': 0.007042253521126761,
#   'move': 0.028169014084507043,
#   'money': 0.007042253521126761,
#   'appeal': 0.007042253521126761,
#   'index': 0.007042253521126761,
#   'effect': 0.007042253521126761,
#   'country': 0.007042253521126761,
#   'jury': 0.007042253521126761,
#   'bid': 0.007042253521126761,
#   'unit': 0.028169014084507043,
#   'eu': 0.007042253521126761,
#   'agenda': 0.007042253521126761,
#   'economy': 0.014084507042253521,
#   'treasury': 0.007042253521126761,
#   'year': 0.007042253521126761,
#   'meeting': 0.007042253521126761,
#   'euro': 0.028169014084507043,
#   'ipo': 0.007042253521126761,
#   'mill': 0.007042253521126761,
#   'globe': 0.007042253521126761,
#   'lawsuit': 0.007042253521126761,
#   'budget': 0.014084507042253521,
#   'administration': 0.007042253521126761,
#   'plan': 0.014084507042253521,
#   'philosopher': 0.007042253521126761,
#   'lse': 0.007042253521126761,
#   'sale': 0.007042253521126761,
#   'information': 0.014084507042253521,
#   'scandal': 0.007042253521126761,
#   'impact': 0.007042253521126761,
#   'fsa': 0.007042253521126761,
#   'cartel': 0.007042253521126761,
#   'rate': 0.014084507042253521,
#   'takeover': 0.007042253521126761,
#   'us': 0.014084507042253521,
#   'restructuring': 0.007042253521126761,
#   'project': 0.014084507042253521,
#   'fix': 0.007042253521126761,
#   'economy]': 0.007042253521126761,
#   'claim': 0.007042253521126761,
#   'us,': 0.007042253521126761,
#   'fund': 0.007042253521126761,
#   'arrest': 0.007042253521126761,
#   'figure': 0.007042253521126761,
#   'buy-back': 0.007042253521126761,
#   'industry': 0.007042253521126761,
#   'pbgc': 0.007042253521126761,
#   'growth': 0.007042253521126761,
#   'ariary': 0.007042253521126761,
#   'up': 0.007042253521126761,
#   'ruling': 0.007042253521126761,
#   'pay-off': 0.007042253521126761,
#   'market,': 0.007042253521126761,
#   'kse': 0.007042253521126761,
#   'decision': 0.007042253521126761,
#   'market': 0.007042253521126761,
#   'article': 0.007042253521126761,
#   'slowdown': 0.007042253521126761,
#   'list': 0.014084507042253521,
#   'merger': 0.007042253521126761,
#   'public': 0.007042253521126761,
#   'listing': 0.007042253521126761,
#   'offer': 0.007042253521126761,
#   'philippines': 0.007042253521126761,
#   'sample': 0.007042253521126761,
#   'traffic': 0.007042253521126761,
#   'trial': 0.007042253521126761},
#  ('government', 'keen'): {'was': 0.5, 'seemed': 0.5},
#  ('keen', 'play'): {'to': 1.0},
#  ('to', 'down'): {'play': 0.0625,
#   'push': 0.125,
#   'back': 0.0625,
#   'october,': 0.0625,
#   'clamp': 0.125,
#   'tear': 0.0625,
#   'step': 0.0625,
#   'bring': 0.0625,
#   'cut': 0.0625,
#   'track': 0.0625,
#   'cool': 0.125,
#   'close': 0.0625,
#   '19.1%,': 0.0625},
#  ('play', 'the'): {'down': 0.6666666666666666, 'by': 0.3333333333333333},
#  ('down', 'worrying'): {'the': 1.0},
#  ('the', 'implications'): {'worrying': 1.0},
#  ('worrying', 'of'): {'implications': 1.0},
#  ('implications', 'the'): {'of': 0.5, 'for': 0.5},
#  ('of', 'data.'): {'the': 1.0},
#  ('the', '"i'): {'data.': 0.2,
#   'allegations.': 0.2,
#   'club.': 0.2,
#   'uk.': 0.2,
#   'future.': 0.2},
#  ('data.', 'maintain'): {'"i': 1.0},
#  ('"i', 'the'): {'maintain': 0.14285714285714285,
#   'think': 0.5714285714285714,
#   'understand': 0.14285714285714285,
#   'believe': 0.14285714285714285},
#  ('maintain', 'view'): {'the': 1.0},
#  ('the', 'that'): {'view': 0.04597701149425287,
#   'revelation': 0.034482758620689655,
#   'risk': 0.011494252873563218,
#   'news': 0.011494252873563218,
#   'fact': 0.1839080459770115,
#   'numbers': 0.011494252873563218,
#   'time': 0.022988505747126436,
#   'court': 0.04597701149425287,
#   'accounts': 0.011494252873563218,
#   'impression': 0.022988505747126436,
#   'vehicles': 0.011494252873563218,
#   'allegation': 0.011494252873563218,
#   'case': 0.011494252873563218,
#   'innovation': 0.011494252873563218,
#   'mpc': 0.011494252873563218,
#   'past': 0.011494252873563218,
#   'growth': 0.011494252873563218,
#   'label': 0.011494252873563218,
#   'state': 0.011494252873563218,
#   'possibility': 0.022988505747126436,
#   'way': 0.011494252873563218,
#   'money': 0.011494252873563218,
#   'market': 0.011494252873563218,
#   'information': 0.011494252873563218,
#   'deficits': 0.011494252873563218,
#   'steps': 0.011494252873563218,
#   'budget': 0.011494252873563218,
#   'bbc': 0.022988505747126436,
#   'debts': 0.011494252873563218,
#   'danger': 0.011494252873563218,
#   'ft': 0.022988505747126436,
#   'amount': 0.011494252873563218,
#   'shares': 0.011494252873563218,
#   'uk': 0.011494252873563218,
#   'damage': 0.011494252873563218,
#   "bottom'": 0.011494252873563218,
#   '$20bn': 0.011494252873563218,
#   'family': 0.022988505747126436,
#   'investigation': 0.011494252873563218,
#   'theory': 0.011494252873563218,
#   'firm': 0.011494252873563218,
#   'belief': 0.011494252873563218,
#   'start': 0.011494252873563218,
#   'tribunal': 0.011494252873563218,
#   'hurricanes': 0.011494252873563218,
#   'moment': 0.011494252873563218,
#   'companies': 0.011494252873563218,
#   'land': 0.011494252873563218,
#   'uncertainty': 0.011494252873563218,
#   'circumstances': 0.011494252873563218,
#   'authority': 0.011494252873563218,
#   'business': 0.011494252873563218,
#   'company': 0.011494252873563218,
#   'role': 0.011494252873563218,
#   'expectation': 0.011494252873563218,
#   'claims': 0.011494252873563218,
#   'event': 0.011494252873563218,
#   'conspiracy,': 0.011494252873563218},
#  ('view', "japan's"): {'that': 1.0},
#  ('that', 'economy'): {"japan's": 0.07692307692307693,
#   'the': 0.6923076923076923,
#   'its': 0.07692307692307693,
#   '"the': 0.07692307692307693,
#   'our': 0.07692307692307693},
#  ("japan's", 'remains'): {'economy': 0.5, 'government': 0.5},
#  ('economy', 'in'): {'remains': 0.125,
#   'evolved': 0.125,
#   'growing': 0.125,
#   'is': 0.25,
#   "'strong'": 0.25,
#   'contracted': 0.125},
#  ('remains', 'a'): {'in': 0.3333333333333333,
#   'at': 0.3333333333333333,
#   'fragile,"': 0.3333333333333333},
#  ('in', 'minor'): {'a': 1.0},
#  ('a', 'adjustment'): {'minor': 1.0},
#  ('minor', 'phase'): {'adjustment': 1.0},
#  ('adjustment', 'in'): {'phase': 1.0},
#  ('phase', 'an'): {'in': 1.0},
#  ('in', 'upward'): {'an': 1.0},
#  ('an', 'climb,'): {'upward': 1.0},
#  ('upward', 'and'): {'climb,': 1.0},
#  ('climb,', 'we'): {'and': 1.0},
#  ('and', 'will'): {'we': 0.08695652173913043,
#   'education': 0.043478260869565216,
#   'sanitation': 0.043478260869565216,
#   'ultimately': 0.043478260869565216,
#   'economies': 0.043478260869565216,
#   'business': 0.08695652173913043,
#   '17': 0.043478260869565216,
#   'relatives': 0.043478260869565216,
#   'parents': 0.043478260869565216,
#   'ntpc': 0.043478260869565216,
#   'exports': 0.043478260869565216,
#   '550': 0.043478260869565216,
#   'people': 0.043478260869565216,
#   'each': 0.043478260869565216,
#   'announcements': 0.043478260869565216,
#   'it': 0.043478260869565216,
#   'contracts': 0.043478260869565216,
#   'india': 0.043478260869565216,
#   'germany': 0.043478260869565216,
#   'southcorp': 0.043478260869565216,
#   'tourism': 0.043478260869565216},
#  ('we', 'monitor'): {'will': 1.0},
#  ('will', 'developments'): {'monitor': 1.0},
#  ('monitor', 'carefully,"'): {'developments': 1.0},
#  ('developments', 'said'): {'carefully,"': 1.0},
#  ('carefully,"', 'economy'): {'said': 1.0},
#  ('said', 'minister'): {'economy': 0.5, 'labour': 0.25, 'finance': 0.25},
#  ('economy', 'heizo'): {'minister': 1.0},
#  ('minister', 'takenaka.'): {'heizo': 1.0},
#  ('heizo', 'but'): {'takenaka.': 1.0},
#  ('takenaka.', 'in'): {'but': 1.0},
#  ('but', 'the'): {'in': 0.15,
#   'under': 0.05,
#   'causes': 0.05,
#   'with': 0.1,
#   'without': 0.05,
#   'meeting': 0.05,
#   'also': 0.05,
#   'despite': 0.05,
#   'when': 0.05,
#   'for': 0.05,
#   'weaker.': 0.05,
#   'of': 0.05,
#   'loosen': 0.05,
#   'while': 0.05,
#   'once': 0.05,
#   'undervalued': 0.05,
#   'not': 0.05},
#  ('in', 'face'): {'the': 1.0},
#  ('face', 'the'): {'of': 0.4, 'is': 0.2, 'on': 0.2, 'in': 0.2},
#  ('of', 'strengthening'): {'the': 1.0},
#  ('the', 'yen'): {'strengthening': 0.25, 'japanese': 0.75},
#  ('strengthening', 'making'): {'yen': 1.0},
#  ('yen', 'exports'): {'making': 1.0},
#  ('making', 'less'): {'exports': 1.0},
#  ('exports', 'competitive'): {'less': 1.0},
#  ('less', 'and'): {'competitive': 1.0},
#  ('competitive', 'indications'): {'and': 1.0},
#  ('and', 'of'): {'indications': 0.02,
#   'operators': 0.02,
#   'part': 0.06,
#   'livelihoods': 0.02,
#   'speed': 0.02,
#   'eva': 0.02,
#   'development': 0.02,
#   'banc': 0.02,
#   'much': 0.04,
#   'embezzlement': 0.02,
#   'troughs': 0.04,
#   'bank': 0.08,
#   'delivery': 0.02,
#   '98%': 0.02,
#   'consists': 0.02,
#   'location': 0.02,
#   'citizens': 0.02,
#   'controller': 0.02,
#   'overheating': 0.02,
#   '12': 0.04,
#   'many': 0.06,
#   'independence': 0.02,
#   'reports': 0.02,
#   'fines': 0.02,
#   'one': 0.04,
#   '98.8%': 0.02,
#   'millions': 0.02,
#   'vice-chairman': 0.02,
#   'sales': 0.02,
#   'head': 0.02,
#   'expense': 0.02,
#   'revenues': 0.04,
#   'production': 0.02,
#   'suspicion': 0.02,
#   'out': 0.02,
#   'earnings': 0.02,
#   'heads': 0.02,
#   'downs': 0.02},
#  ('indications', 'weakening'): {'of': 1.0},
#  ('of', 'economic'): {'weakening': 0.05,
#   'us': 0.1,
#   'lords': 0.05,
#   'future': 0.05,
#   'government': 0.05,
#   'all': 0.1,
#   'growing': 0.05,
#   'an': 0.05,
#   'his': 0.05,
#   'global': 0.1,
#   'the': 0.05,
#   'doubled': 0.05,
#   'solid': 0.05,
#   'strong': 0.05,
#   '"golden"': 0.05,
#   'blistering': 0.05,
#   "china's": 0.05},
#  ('weakening', 'conditions'): {'economic': 1.0},
#  ('economic', 'ahead,'): {'conditions': 1.0},
#  ('conditions', 'observers'): {'ahead,': 1.0},
#  ('ahead,', 'were'): {'observers': 1.0},
#  ('observers', 'less'): {'were': 1.0},
#  ('were', 'sanguine.'): {'less': 1.0},
#  ...}

# %%
first_order[('going')]
# Out:
# {'abroad,': 1.0}

# %%
def sample_word(d):
  p0 = np.random.random()
  cumulative = 0
  for t, p in d.items():
    cumulative += p
    if p0 < cumulative:
      return t
  assert(False) # should never get here

# %%
def spin_sentence(old_sentence_list):
    sentence_list=old_sentence_list
    if sentence_list!=[]:
        for word_idx, word in enumerate(sentence_list):
            if word_idx!=0 and word_idx!=len(sentence_list)-1:
                t_m1 = sentence_list[word_idx-1]
                t_p1 = sentence_list[word_idx+1]
                key = (t_m1, t_p1)
                p_dist = second_order[key]
                # Alter 40% of changeable words
                if len(p_dist)>1 and np.random.random()<0.40:
                    new_word = sample_word(p_dist)
                    sentence_list[word_idx] = new_word
    return sentence_list

# %%
doc_idx=1
sen_idx=3
print(filtered_tokens[doc_idx][sen_idx])
#spin_sentence(filtered_tokens[doc_idx][sen_idx])
# Out:
# ['rosneft', 'officials', 'were', 'unavailable', 'for', 'comment.', 'but', 'the', 'company', 'has', 'said', 'it', 'intends', 'to', 'take', 'action', 'against', 'menatep', 'to', 'recover', 'some', 'of', 'the', 'tax', 'claims', 'and', 'debts', 'owed', 'by', 'yugansk.', 'yukos', 'had', 'filed', 'for', 'bankruptcy', 'protection', 'in', 'a', 'us', 'court', 'in', 'an', 'attempt', 'to', 'prevent', 'the', 'forced', 'sale', 'of', 'its', 'main', 'production', 'arm.', 'the', 'sale', 'went', 'ahead', 'in', 'december', 'and', 'yugansk', 'was', 'sold', 'to', 'a', 'little-known', 'shell', 'company', 'which', 'in', 'turn', 'was', 'bought', 'by', 'rosneft.', 'yukos', 'claims', 'its', 'downfall', 'was', 'punishment', 'for', 'the', 'political', 'ambitions', 'of', 'its', 'founder', 'mikhail', 'khodorkovsky', 'and', 'has', 'vowed', 'to', 'sue', 'any', 'participant', 'in', 'the', 'sale.']

# %%
filtered_tokens[doc_idx][sen_idx]
# Out:
# ['rosneft',
#  'officials',
#  'were',
#  'unavailable',
#  'for',
#  'comment.',
#  'but',
#  'the',
#  'company',
#  'has',
#  'said',
#  'it',
#  'intends',
#  'to',
#  'take',
#  'action',
#  'against',
#  'menatep',
#  'to',
#  'recover',
#  'some',
#  'of',
#  'the',
#  'tax',
#  'claims',
#  'and',
#  'debts',
#  'owed',
#  'by',
#  'yugansk.',
#  'yukos',
#  'had',
#  'filed',
#  'for',
#  'bankruptcy',
#  'protection',
#  'in',
#  'a',
#  'us',
#  'court',
#  'in',
#  'an',
#  'attempt',
#  'to',
#  'prevent',
#  'the',
#  'forced',
#  'sale',
#  'of',
#  'its',
#  'main',
#  'production',
#  'arm.',
#  'the',
#  'sale',
#  'went',
#  'ahead',
#  'in',
#  'december',
#  'and',
#  'yugansk',
#  'was',
#  'sold',
#  'to',
#  'a',
#  'little-known',
#  'shell',
#  'company',
#  'which',
#  'in',
#  'turn',
#  'was',
#  'bought',
#  'by',
#  'rosneft.',
#  'yukos',
#  'claims',
#  'its',
#  'downfall',
#  'was',
#  'punishment',
#  'for',
#  'the',
#  'political',
#  'ambitions',
#  'of',
#  'its',
#  'founder',
#  'mikhail',
#  'khodorkovsky',
#  'and',
#  'has',
#  'vowed',
#  'to',
#  'sue',
#  'any',
#  'participant',
#  'in',
#  'the',
#  'sale.']

# %%
p0 = np.random.random()
print("p0 = ",p0)
cumulative = 0
for t1, p1 in first_order[t].items():
    if p1==1.0:
        print("word = ",t1)
        break
    cumulative += p
    if p0 < cumulative:
        print("cumulative = ",cumulative)
        print("word = ",t1)
        break
# Out:
# p0 =  0.5425443680112613
# word =  cards

# %%
for t1, p1 in first_order[t].items():
    print(p1)
# Out:
# 1.0

# %%
p0 = np.random.random()
print("p0 = ",p0)
cumulative = 0
for t2, p2 in second_order[t,t1].items():
    if p2==1.0:
        print("word = ",t2)
        break
    cumulative += p
    if p0 < cumulative:
        print("cumulative = ",cumulative)
        print("word = ",t2)
        break
# Out:
# p0 =  0.14217004760152696
# word =  one

# %%
def generator(initial_d, first_d, second_d, max_words):
    words=[]
    counter=0
    current_word=' '
    
    word1=sample_word(initial_d)
    words.append(word1)
    word2=sample_word(first_d[word1])
    words.append(word2)
    while(word2!="END" and counter<max_words-2):
        current_word = word2
        word2 = sample_word(second_d[word1,word2])
        word1 = current_word
        words.append(word2)
        counter+=1
    # Create a new list with 'END' replaced by '.'
    new_list_of_words = ['.' if word == 'END' else word for word in words]
    sentence = ' '.join(new_list_of_words)
    print(sentence)

# %%
for generations in range(4):
    max_words = np.random.choice([5,12])
    generator(initial,first_order,second_order,max_words)
# Out:
# i have looked as if
# with his pipe in his mouth and his brown jug .
# though not yet all gone
# halting perplexed behind the mountains

# %%
def generate():
  for i in range(4): # generate 4 lines
    sentence = []

    # initial word
    w0 = sample_word(initial)
    sentence.append(w0)

    # sample second word
    w1 = sample_word(first_order[w0])
    sentence.append(w1)

    # second-order transitions until END
    while True:
      w2 = sample_word(second_order[(w0, w1)])
      if w2 == 'END':
        break
      sentence.append(w2)
      w0 = w1
      w1 = w2
    print(' '.join(sentence))

# %%
generate()
# Out:
# and not melt snow or start a dormant tree
# like some men folk no ones afraid of fire
# into each other i know the country and now the very air of what i think ill get away
# and i
